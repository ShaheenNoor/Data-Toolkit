# %% [markdown]
# 1- What is NumPy, and why is it widely used in Python?
# Ans- NumPy is a Python library used for numerical computing. It provides support for large, multi-dimensional arrays and matrices, along with many mathematical functions to operate on them efficiently.
#
# It's widely used because it's fast, memory-efficient, and forms the foundation for many other libraries like pandas, scikit-learn, and TensorFlow.
#
# 2- How does broadcasting work in NumPy?
# Ans- Broadcasting lets NumPy perform operations on arrays of different shapes by automatically expanding smaller arrays to match the larger one's shape.
#
# 3- What is a Pandas DataFrame?
# Ans- A Pandas DataFrame is a 2D labeled data structure in Python, like a table with rows and columns, used to store and manipulate data easily.
#
# 4- Explain the use of the groupby() method in Pandas?
# Ans- The groupby() method in Pandas is used to group data based on one or more columns and then apply functions like sum, mean, or count to each group.
#
# 5- Why is Seaborn preferred for statistical visualizations?
# Ans- Seaborn is preferred because it makes creating attractive, informative statistical graphs easy with simple code and integrates well with Pandas.
#
# 6- What are the differences between NumPy arrays and Python lists?
# Ans- NumPy arrays are faster and use less memory.
# They support vectorized operations (no loops need).
# All elements in a NumPy array must be of the same type, unlike Python lists.
#
# 7- What is a heatmap, and when should it be used?
# Ans A heatmap is a visual representation of data using colors to show values. It's used to display correlations or patterns in data, like relationships between variables.
#
# 8- What does the term “vectorized operation” mean in NumPy?
# Ans- Vectorized operation means performing computations on entire arrays without using loops, making the code faster and more efficient.
#
# 9- How does Matplotlib differ from Plotly?
# Ans- Matplotlib creates static, simple plots, while Plotly makes interactive, web-based visualizations with zoom and hover features.
#
# 10- What is the significance of hierarchical indexing in Pandas?
# Ans- Hierarchical indexing allows multiple levels of indexes in Pandas, making it easier to handle and analyze multi-dimensional data.
#
# 11- What is the role of Seaborn's pairplot() function?
# Ans- The pairplot() function in Seaborn shows relationships between multiple variables by plotting pairwise scatter plots and histograms.
#
# 12- What is the purpose of the describe() function in Pandas?
# Ans- The describe() function in Pandas gives summary statistics like mean, median, count, and standard deviation for each column in a dataset.
#
# 13- Why is handling missing data important in Pandas?
# Ans- Handling missing data is important to ensure accurate analysis, as missing values can lead to wrong results or errors in calculations.
#
# 14- What are the benefits of using Plotly for data visualization?
# Ans- Plotly creates interactive, high-quality, and web-friendly visualizations that allow zooming, hovering, and real-time data exploration.
#
# 15- How does NumPy handle multidimensional arrays?
# Ans- NumPy handles multidimensional arrays using the ndarray object, which stores data in grids with any number of dimensions (1D, 2D, 3D, etc.).
#
# 16- What is the role of Bokeh in data visualization?
# Ans- Bokeh is used to create interactive, web-based visualizations that can handle large datasets and display them in browsers easily.
#
# 17- Explain the difference between apply() and map() in Pandas.
# Ans- map() works on a single column or Series to apply a function, while apply() can be used on both DataFrames and Series to apply a function to rows or columns.
#
# 18- What are some advanced features of NumPy?
# Ans- Advanced features of NumPy include broadcasting, vectorization, linear algebra operations, random number generation, and fast Fourier transforms (FFT).
#
# 19- How does Pandas simplify time series analysis?
# Ans- Pandas simplifies time series analysis with built-in tools for date handling, resampling, shifting, and rolling window calculations.
#
# 20- What is the role of a pivot table in Pandas?
# Ans- A pivot table in Pandas summarizes data by grouping and aggregating values, making it easy to analyze relationships between columns.
#
# 21- Why is NumPy's array slicing faster than Python's list slicing?
# Ans- NumPy's array slicing is faster because it uses fixed-type, contiguous memory storage and avoids creating data copies, unlike Python lists.
#
# 22- What are some common use cases for Seaborn?
# Ans- Common use cases for Seaborn include visualizing distributions, correlations, categorical data, and creating plots like heatmaps, boxplots, and pairplots.

# %% [markdown]
# 1- How do you create a 2D NumPy array and calculate the sum of each row?

# %%
import numpy as np

# create 2D array
arr = np.array([[1, 2, 3], [4, 5, 6]])

# sum of each row
row_sum = np.sum(arr, axis=1)

print(row_sum)
# Out:
# [ 6 15]

# %% [markdown]
# 2-Write a Pandas script to find the mean of a specific column in a DataFrame?

# %%
import pandas as pd

# create DataFrame
data = {'A': [10, 20, 30, 40], 'B': [5, 15, 25, 35]}
df = pd.DataFrame(data)

# find mean of column 'A'
mean_A = df['A'].mean()

print("Mean of column A:", mean_A)
# Out:
# Mean of column A: 25.0

# %% [markdown]
# 3- Create a scatter plot using MatplotlibA?

# %%
import matplotlib.pyplot as plt

# sample data
x = [1, 2, 3, 4, 5]
y = [5, 7, 9, 6, 8]

# create scatter plot
plt.scatter(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Scatter Plot')
plt.show()

# %% [markdown]
# 4- How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap?

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# create sample DataFrame
data = {'A': [1, 2, 3, 4], 'B': [4, 5, 6, 7], 'C': [7, 8, 9, 10]}
df = pd.DataFrame(data)

# calculate correlation matrix
corr = df.corr()

# visualize with heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# 5- Generate a bar plot using Plotly.

# %%
import plotly.express as px

# sample data
data = {'Fruits': ['Apple', 'Banana', 'Orange'], 'Quantity': [10, 15, 7]}

# create bar plot
fig = px.bar(data, x='Fruits', y='Quantity', title='Fruit Quantity')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 6- Create a DataFrame and add a new column based on an existing column.

# %%
import pandas as pd

# create DataFrame
df = pd.DataFrame({'A': [10, 20, 30, 40]})

# add new column based on existing one
df['B'] = df['A'] * 2

print(df)
# Out:
#     A   B
# 0  10  20
# 1  20  40
# 2  30  60
# 3  40  80

# %% [markdown]
# 7- Write a program to perform element-wise multiplication of two NumPy arrays?

# %%
import numpy as np

# create two arrays
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# element-wise multiplication
result = a * b

print(result)
# Out:
# [ 4 10 18]

# %% [markdown]
# 8- Create a line plot with multiple lines using Matplotlib?

# %%
import matplotlib.pyplot as plt

# sample data
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
y2 = [1, 3, 5, 7, 9]

# create multiple line plot
plt.plot(x, y1, label='Line 1')
plt.plot(x, y2, label='Line 2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Line Plot')
plt.legend()
plt.show()

# %% [markdown]
# 9- Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold?

# %%
import pandas as pd

# create DataFrame
df = pd.DataFrame({'A': [10, 25, 30, 15, 40]})

# filter rows where column 'A' > 20
filtered_df = df[df['A'] > 20]

print(filtered_df)
# Out:
#     A
# 1  25
# 2  30
# 4  40

# %% [markdown]
# 10-Create a histogram using Seaborn to visualize a distribution.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# sample data
data = [5, 7, 8, 5, 6, 9, 10, 6, 7, 8]

# create histogram
sns.histplot(data, bins=5, kde=True)
plt.title('Data Distribution')
plt.show()

# %% [markdown]
# 11- Perform matrix multiplication using NumPy?

# %%
import numpy as np

# create two matrices
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# matrix multiplication
result = np.dot(A, B)

print(result)
# Out:
# [[19 22]
#  [43 50]]

# %% [markdown]
# 12- Use Pandas to load a CSV file and display its first 5 rows.

# %%
# dummy CSV file for demonstration
dummy_data = {'col1': [1, 2, 3, 4, 5], 'col2': ['A', 'B', 'C', 'D', 'E']}
dummy_df = pd.DataFrame(dummy_data)
dummy_df.to_csv('data.csv', index=False)

# %%
import pandas as pd

# load CSV file
df = pd.read_csv('data.csv')

# display first 5 rows
print(df.head())
# Out:
#    col1 col2
# 0     1    A
# 1     2    B
# 2     3    C
# 3     4    D
# 4     5    E

# %% [markdown]
# 13-Create a 3D scatter plot using Plotly.

# %%
import plotly.express as px
import pandas as pd

# sample data
data = pd.DataFrame({
    'x': [1, 2, 3, 4, 5],
    'y': [10, 11, 12, 13, 14],
    'z': [5, 6, 7, 8, 9]
})

# create 3D scatter plot
fig = px.scatter_3d(data, x='x', y='y', z='z', title='3D Scatter Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
